# %% [markdown]
# <a href="https://colab.research.google.com/github/archivesunleashed/notebooks/blob/main/arch/audio-information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Audio Information Dataset Exploration
#
# We're going to take a look at a few examples of how we can explore the Audio Information dataset.
#
# The first thing we need to do is enter the URL for our Audio Information dataset in the cell below. You can get this by right clicking the Download icon, and selecting "Copy Link".

# %%
dataset = 'https://webdata.archive-it.org/ait/files/download/ARCHIVEIT-03010/AudioInformationExtraction/audio-information.csv.gz?access=ZJP74KT337WMAA2TNCJCHAR76DY3WZ3I' #@param {type:"string"}
print(dataset)
# Out:
# https://webdata.archive-it.org/ait/files/download/ARCHIVEIT-03010/AudioInformationExtraction/audio-information.csv.gz?access=ZJP74KT337WMAA2TNCJCHAR76DY3WZ3I

# %% [markdown]
# ## pandas
#
# Next, we'll setup our environment so we can load our Audio Information dataset into [pandas](https://pandas.pydata.org) DataFrames. If you're unfamiliar with DataFrames, but you've worked with spreadsheets before, you should quickly feel comfortable.

# %%
import pandas as pd

# %% [markdown]
# ## Data Table Display
#
# Colab includes an extension that renders pandas DataFrames into interactive displays that can be filtered, sorted, and explored dynamically. This can be very useful for taking a look at what each DataFrame provides, and doing some intital filtering!
#
# Data table display for pandas dataframes can be enabled by running:
# ```python
# %load_ext google.colab.data_table
# ```
# and disabled by running
# ```python
# %unload_ext google.colab.data_table
# ```

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# ## Loading our ARCH Dataset as a DataFrame
#
# ---
#
#
# Next, we'll create pandas DataFrame from our dataset, and show a preview of it using the Data Table Display.

# %%
audio = pd.read_csv(dataset, compression='gzip')
audio
# Out:
#      crawl_date                                                url  \
# 0      20120118  http://www.wgmd.com/wp-content/uploads/2010/09...
# 1      20120118  http://cdn05.hulkshare.com/dev5/0/002/287/0002...
# 2      20120118  http://cdn03.hulkshare.com/dev3/0/002/296/0002...
# 3      20120118              http://t-robots.org/podcasts/test.mp3
# 4      20120118  http://dawnxianamoon.com/music/Dawn_Xiana_Moon...
# ..          ...                                                ...
# 236    20120118  http://cdn06.hulkshare.com/dev6/0/002/287/0002...
# 237    20120118  http://cdn02.hulkshare.com/dev2/0/003/203/0003...
# 238    20120118  http://cdn06.hulkshare.com/dev6/0/003/208/0003...
# 239    20120118  http://podcast.raggakings.net/vibespromotion/2...
# 240    20120118  http://tropicalbass.com/mixes/Marflix-RiddimsT...
#
#                                               filename extension  \
# 0                               christine-odonnell.mp3       mp3
# ...

# %% [markdown]
# # Data Analysis
#
# Now that we have all of our datasets loaded up, we can begin to work with them!

# %% [markdown]
# ## Counting total files, and unique files
#
# Let's take a quick look at how to count items in DataFrames, and use total and unique files as an example to work with.
#
# It's definitely worth checking out the [pandas documentation](https://pandas.pydata.org/docs/index.html). There are a lot of good examples available, along with a robust [API reference](https://pandas.pydata.org/docs/reference/index.html#api).

# %% [markdown]
# ### How many audio files are in this collection?
#
# We can take our `audio` variable try a couple of functions to get the same answer.
#
# 1.   `len(audio.index)`
#   * Get the length of the DataFrame's index.
# 2.   `audio.shape[0]`
#   * Get the shape or dimensionality of the DataFrame, and take the first item in the tuple.
# 3.  `audio.count()`
#   * Count the number of rows for each column.

# %%
len(audio.index)
# Out:
# 241

# %%
audio.shape[0]
# Out:
# 241

# %%
audio.count()
# Out:
# crawl_date              241
# url                     241
# filename                241
# extension               241
# mime_type_web_server    241
# mime_type_tika          241
# md5                     241
# sha1                    241
# dtype: int64

# %% [markdown]
# ### How many unique audio files are in the collection?
#
#  We can see if an audio file is unique or not by computing an [MD5 hash](https://en.wikipedia.org/wiki/MD5#MD5_hashes) of it, and comparing them. The exact same audio file might have a filename of `example.jpg` or `foo.jpg`. If the hash is computed for each, we can see that even with different file names, they are actually the same audio file. So, since we have both a `MD5` and `SHA1` hash column available in our DataFrame, we can just find the unique values, and count them!

# %%
len(audio.md5.unique())
# Out:
# 153

# %% [markdown]
# ### What are the top 10 most occurring audio files in the collection?
#
# Here we can take advantage of [`value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html) to provide us with a list of MD5 hashes, and their respective counts.

# %%
audio["md5"].value_counts().head(10)
# Out:
# 6ce4a55023ebebe48155923e21a9ac45    5
# 57702671c1462a226f1130d9c4ce1775    3
# c22b2e17b7c329b1c2e7e7ddf356209a    2
# b1bf8a6f275174d79b17188819b32124    2
# 6586152af032d93380fcbe435cad9087    2
# cdc06e40629db836bbba0eabf4b3e9ac    2
# f0a2c3b1dea3e5fee439361c3cbd60ae    2
# cfbb61beda7872de8805abe7a102f149    2
# 447f043693bd7619a9949ae6d39a5609    2
# b388f1323abff3ec3b34130fa20acaa5    2
# Name: md5, dtype: int64

# %% [markdown]
# ### What's the information around all of the occurances of `6ce4a55023ebebe48155923e21a9ac45`?
#
# What, you mean you don't know what `6ce4a55023ebebe48155923e21a9ac45` means?
#
# Let's find those audio files in the DataFrame. We can here see some of the filenames used, its dimensions, and its URL.

# %%
audio.loc[audio["md5"] == "6ce4a55023ebebe48155923e21a9ac45"]
# Out:
#      crawl_date                                                url  \
# 39     20120118  http://xnite.org/wp-content/plugins/mp3-jplaye...
# 51     20120118  http://contzius.com/wp/wp-content/plugins/mp3-...
# 132    20120118  http://sharkattackmedia.com/wp-content/plugins...
# 201    20120118  http://contzius.com/wp/wp-content/plugins/mp3-...
# 206    20120118  http://xnite.org/wp-content/plugins/mp3-jplaye...
#
#         filename extension mime_type_web_server mime_type_tika  \
# 39   silence.mp3       mp3           audio/mpeg     audio/mpeg
# 51   silence.mp3       mp3           audio/mpeg     audio/mpeg
# 132  silence.mp3       mp3           audio/mpeg     audio/mpeg
# 201  silence.mp3       mp3           audio/mpeg     audio/mpeg
# 206  silence.mp3       mp3           audio/mpeg     audio/mpeg
#
#                                   md5  \
# 39   6ce4a55023ebebe48155923e21a9ac45
# 51   6ce4a55023ebebe48155923e21a9ac45
# 132  6ce4a55023ebebe48155923e21a9ac45
# ...

# %% [markdown]
# ### What are the top 10 most occuring filenames in the collection?
#
# Note that this is of course different than the MD5 results up above. Here we are focusing _just_ on filename. So `silence.mp3` for example, might actually be referring to different audio files who happen to have the same name.
#
# Here we can use `value_counts()` again, but this time we'll create a variable for the top filenames so we can use it later.

# %%
top_filenames = audio["filename"].value_counts().head(10)
top_filenames
# Out:
# silence.mp3                           5
# Swag.mp3                              4
# The_Omen_-_Ave_Satani.wav             3
# stephenfewell_-_Idealistic_Kid.mp3    2
# Sprils.mp3                            2
# Sihys.mp3                             2
# Rxdiety.mp3                           2
# Otsq.mp3                              2
# Mm.mp3                                2
# Ltb.mp3                               2
# Name: filename, dtype: int64

# %% [markdown]
# ### Let's create our first graph!
#
# We'll plot the data first with pandas [plot](https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.html) functionality, and then plot the data with [Altair](https://altair-viz.github.io/).

# %%
top_filenames_chart = top_filenames.plot.bar(figsize=(25, 10))

top_filenames_chart.set_title("Top Filenames", fontsize=22)
top_filenames_chart.set_xlabel("Filename", fontsize=20)
top_filenames_chart.set_ylabel("Count", fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Now let's set up [Altair](https://altair-viz.github.io/), and plot the data with Altair. Altair is useful for creating visualizations since they can be easily exported as a PNG or SVG.

# %%
import altair as alt

# %%
top_filenames_altair = (
    audio["filename"]
    .value_counts()
    .head(10)
    .rename_axis("Filename")
    .reset_index(name="Count")
)

filenames_bar = (
    alt.Chart(top_filenames_altair)
    .mark_bar()
    .encode(x=alt.X("Filename:O", sort="-y"), y=alt.Y("Count:Q"))
)

filenames_rule = (
    alt.Chart(top_filenames_altair).mark_rule(color="red").encode(y="mean(Count):Q")
)


filenames_text = filenames_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(filenames_bar + filenames_rule + filenames_text).properties(
    width=1400, height=700, title="Top Filenames"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### How about a file format distribution?
#
# What _kind_ of audio files are present? We can discover this by checking their "media type", or [MIME type](https://en.wikipedia.org/wiki/Media_type).

# %%
audio_mime_types = (
    audio["mime_type_tika"]
    .value_counts()
    .head(5)
    .rename_axis("MIME Type")
    .reset_index(name="Count")
)

audio_mimes_bar = (
    alt.Chart(audio_mime_types)
    .mark_bar()
    .encode(x=alt.X("MIME Type:O", sort="-y"), y=alt.Y("Count:Q"))
)

audio_mime_rule = (
    alt.Chart(audio_mime_types).mark_rule(color="red").encode(y="mean(Count):Q")
)

audio_mime_text = audio_mimes_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(audio_mimes_bar + audio_mime_rule + audio_mime_text).properties(
    width=1400, height=700, title="Audio File Format Distribution"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### How do I get the actual audio?
#
# ...or, how do I get to the actual binary files described by each file format information derivative?
#
# There are a few options!
#
# 1. `wget` or `curl` from the live URL, or a replay URL
#   * Live web URL
#     * `wget` or `curl` the value of the `url` column
#   * Replay web URL
#     * `wget` or `curl` the value of the `crawl_date` and `url` column using the following pattern:
#       * `https://web.archive.org/web/` + `crawl_date` + `/` + `url`
#         * https://web.archive.org/web/20120119124734/http://www.archive.org/images/glogo.png
#       * `http://wayback.archive-it.org/14462/` + `crawl_date` + `/` + `url`
#         * https://wayback.archive-it.org/14462/20210524212740/https://ruebot.net/visualization/elxn42/featured_hu33a17dfb90e2c5ed77f783db14a6e53a_5126291_550x0_resize_q90_box_2.png
# 2. Use a scripting language, such as Python
#   * Make use of the `url` and `filename` columns (and `crawl_date` if you want to use the replay URL)
#   * `import requests`
#   * `requests.get(url, allow_redirects=True)`
#   * `open('filename', 'wb').write(r.content)`
# 3. Use the [Archives Unleashed Toolkit](https://aut.docs.archivesunleashed.org/docs/extract-binary) (if you have access to the W/ARC files).

# %% [markdown]
# If you wanted to download the audio files using the replay URL, below a method for doing so.
#
# First, you'll want to setup a replay url base url. Here we'll use the Archive-It Wayback instance for the collection.

# %%
wayback_url = 'http://wayback.archive-it.org/89/'

# %% [markdown]
# Next, we'll create a new column using a lambda function. If you're familiar with working in spreadsheets, what we're doing here is basically concatenating some column values together and creating a new column.

# %%
audio['replay_url'] = audio.apply(lambda row: str(wayback_url + str(row['crawl_date']) + "/" + row['url']), axis=1)

# %% [markdown]
# Then we can export that new column we created out to a file, so we can use it with `wget` to download all the audio files!

# %%
audio['replay_url'].to_csv('89_audio_urls.txt', index=False, header=False)

# %% [markdown]
# Finally, we can pass the file to `wget` to use as a download list. You can also speed this process up using `xargs` or `parallel`.

# %%
# !wget --random-wait -i 89_audio_urls.txt
# Out:
# --2022-11-24 02:22:41--  http://wayback.archive-it.org/89/20120118/http://www.wgmd.com/wp-content/uploads/2010/09/christine-odonnell.mp3
# Resolving wayback.archive-it.org (wayback.archive-it.org)... 207.241.232.8, 207.241.225.8
# Connecting to wayback.archive-it.org (wayback.archive-it.org)|207.241.232.8|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘christine-odonnell.mp3’
#
# christine-odonnell.     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 02:22:41 (25.9 MB/s) - ‘christine-odonnell.mp3’ saved [4613]
#
# --2022-11-24 02:22:41--  http://wayback.archive-it.org/89/20120118/http://cdn05.hulkshare.com/dev5/0/002/287/0002287356.fid/Drake_-_Doing_It_Wrong_Instrumental.mp3?key=1f250e666716530893fc7aef256cc0d1&dl=1
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# ...
