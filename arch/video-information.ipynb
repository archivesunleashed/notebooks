# %% [markdown]
# <a href="https://colab.research.google.com/github/archivesunleashed/notebooks/blob/main/arch/video-information.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video Information Dataset Exploration
#
# We're going to take a look at a few examples of how we can explore the Video Information dataset.
#
# The first thing we need to do is enter the URL for our Video Information dataset in the cell below. You can get this by right clicking the Download icon, and selecting "Copy Link".

# %%
dataset = 'https://webdata.archive-it.org/ait/files/download/ARCHIVEIT-03010/VideoInformationExtraction/video-information.csv.gz?access=2KVSJCA3MDKQNTQLPLINY7S6SWOQKMI7' #@param {type:"string"}
print(dataset)
# Out:
# https://webdata.archive-it.org/ait/files/download/ARCHIVEIT-03010/VideoInformationExtraction/video-information.csv.gz?access=2KVSJCA3MDKQNTQLPLINY7S6SWOQKMI7

# %% [markdown]
# ## pandas
#
# Next, we'll setup our environment so we can load our Video Information dataset into [pandas](https://pandas.pydata.org) DataFrames. If you're unfamiliar with DataFrames, but you've worked with Spreadsheets before, you should feel comfortable pretty quick.

# %%
import pandas as pd

# %% [markdown]
# ## Data Table Display
#
# Colab includes an extension that renders pandas DataFrames into interactive displays that can be filtered, sorted, and explored dynamically. This can be very useful for taking a look at what each DataFrame provides, and doing some intital filtering!
#
# Data table display for pandas DataFrames can be enabled by running:
# ```python
# %load_ext google.colab.data_table
# ```
# and disabled by running
# ```python
# %unload_ext google.colab.data_table
# ```

# %%
# %load_ext google.colab.data_table

# %% [markdown]
# ## Loading our ARCH Dataset as a DataFrame
#
# ---
#
#
# Next, we'll create pandas DataFrame from our dataset, and show a preview of it using the Data Table Display.

# %%
video = pd.read_csv(dataset, compression='gzip')
video
# Out:
#     crawl_date                                                url  \
# 0     20120118  http://rawreplaymedia.com/media/2011/1111/sopa...
# 1     20120118  http://v.tumblr.com/tumblr_lklm9ulRc41qe3twr_r...
# 2     20120118  http://vt.tumblr.com/tumblr_lrmu4x31Bf1qf1zsf.mp4
# 3     20120118  http://vt.tumblr.com/tumblr_lxl7ypR3p21qggwnf.mp4
# 4     20120118  http://v.tumblr.com/tumblr_lxz2e036hr1qebu2l_r...
# ..         ...                                                ...
# 74    20120118  http://videos.videopress.com/P6lGryVS/medium_s...
# 75    20120118  http://videos.videopress.com/QOMfLyhd/medium_s...
# 76    20120118  http://videos.videopress.com/kAklr7b3/medium1_...
# 77    20120118  http://videos.videopress.com/uOAvoIIV/medium2_...
# 78    20120118  http://videos.videopress.com/RmvNfrSj/medium3_...
#
#                            filename extension mime_type_web_server  \
# 0    sopafairuseprotest_120117b.mp4       mp4            video/mp4
# 1   tumblr_lklm9ulRc41qe3twr_r1.mov       mp4      video/quicktime
# 2      tumblr_lrmu4x31Bf1qf1zsf.mp4        qt            video/mp4
# 3      tumblr_lxl7ypR3p21qggwnf.mp4        qt            video/mp4
# 4   tumblr_lxz2e036hr1qebu2l_r1.mov       m4v      video/quicktime
# ..                              ...       ...                  ...
# 74                   medium_std.mp4        qt            video/mp4
# 75                   medium_std.mp4        qt            video/mp4
# 76                  medium1_std.mp4        qt            video/mp4
# 77                  medium2_std.mp4        qt            video/mp4
# 78                  medium3_std.mp4        qt            video/mp4
#
#      mime_type_tika                               md5  \
# 0         video/mp4  4234ee3450e3b7f121f496afc891eac1
# 1         video/mp4  c0b56530a493d9596424a79135155cf4
# 2   video/quicktime  1d7ae145e229df40eaf762e4ede6eec8
# 3   video/quicktime  302711ec6b17c8333e19794a085f580c
# 4       video/x-m4v  22dcaa50ac0b5c9e93e6d1f67cebe5de
# ..              ...                               ...
# 74  video/quicktime  ae8c0cffa6c02f09216c3452b0261a09
# 75  video/quicktime  13a5d6afc7a934589de5db6d0818a521
# 76  video/quicktime  faf5737db21b402c8d28bc05ccd4add6
# 77  video/quicktime  aede71eb02dbfe697442b1dac4220acf
# 78  video/quicktime  25d638c51b007104a4fcc6fee2106c8d
#
#                                         sha1
# 0   cbf21bb9b1fa1b969184fcbe4334e8c7ffb109f4
# 1   41ee4a462d18a7bdc59cad480e110b84c7e6913b
# 2   b91c36a03b4f973d32b7884a357a46ea8b8a6a59
# 3   8908f2e95d9c61147e359ebe477033665fa1b440
# 4   87f5536e2049e34d113670b1cf1b61d330844623
# ..                                       ...
# 74  b88f2943a3c5eb3a0e50006311ff57f1099ba486
# 75  c1eef69b19b3bc2f58ab8eb656df812a4fd49216
# 76  85ecf21f10d7a761378d17db3dbafca6c4f8f092
# 77  1e51f9fcd422c193f12617c580bb424dc67c1ca3
# 78  839e03acdb8497951cabbb9a269edefc42bf63f9
#
# [79 rows x 8 columns]

# %% [markdown]
# # Data Analysis
#
# Now that we have all of our datasets loaded up, we can begin to work with them!

# %% [markdown]
# ## Counting total files, and unique files
#
# Let's take a quick look at how to count items in DataFrames, and use total and unique files as an example to work with.
#
# It's definitely work checking out the [pandas documentation](https://pandas.pydata.org/docs/index.html). There are a lot of good examples available, along with a robust [API reference](https://pandas.pydata.org/docs/reference/index.html#api).

# %% [markdown]
# ### How many video files are in this collection?
#
# We can take our `video` variable and try a couple of functions to get the same answer.
#
# 1.   `len(video.index)`
#   * Get the length of the DataFrame's index.
# 2.   `video.shape[0]`
#   * Get the shape or dimensionality of the DataFrame, and take the first item in the tuple.
# 3.  `video.count()`
#   * Count the number of rows for each column.

# %%
len(video.index)
# Out:
# 79

# %%
video.shape[0]
# Out:
# 79

# %%
video.count()
# Out:
# crawl_date              79
# url                     79
# filename                79
# extension               79
# mime_type_web_server    79
# mime_type_tika          79
# md5                     79
# sha1                    79
# dtype: int64

# %% [markdown]
# ### How many unique video fiels are in the collection?
#
#  We can see if a video files is unique or not by computing an [MD5 hash](https://en.wikipedia.org/wiki/MD5#MD5_hashes) of it, and comparing them. The exact same video file might have a filename of `example.mov` or `foo.mov`. If the hash is computed for each, we can see that even with different file names, they are actually the same video file. So, since we have both a `MD5` and `SHA1` hash column available in our DataFrame, we can just find the unique values, and count them!

# %%
len(video.md5.unique())
# Out:
# 59

# %% [markdown]
# ### What are the top 10 most occurring video files in the collection?
#
# Here we can take advantage of [`value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html) to provide us with a list of MD5 hashes and their respective counts.

# %%
video["md5"].value_counts().head(10)
# Out:
# d5d1475bd4bf11256459328e7bf42e2a    4
# 4234ee3450e3b7f121f496afc891eac1    2
# 5fccb60073b4132d343ac43b20d168e8    2
# 503a00599f00e26ad947aeb5efa4389f    2
# c0b56530a493d9596424a79135155cf4    2
# e7164c8c38a4612a98a2165fc19c436f    2
# c0df196ae905a652dcb73f8867761418    2
# 47df8be2b71ff93fc5ce9c62705268a9    2
# ac5d1170829ca5a72bf16e4e1112a67f    2
# 2b1929bdff9394910a7c7f85871bb19d    2
# Name: md5, dtype: int64

# %% [markdown]
# ### What's the information around all of the occurances of `d5d1475bd4bf11256459328e7bf42e2a`?
#
# What, you mean you don't know what `d5d1475bd4bf11256459328e7bf42e2a` means?
#
# Let's find those video files in the DataFrame. We can here see some of the filenames used and information about the files.

# %%
video.loc[video["md5"] == "d5d1475bd4bf11256459328e7bf42e2a"]
# Out:
#     crawl_date                                                url  \
# 8     20120118  http://www.arckinteractive.com/sopa/monkey_vs_...
# 10    20120118  http://www.vizemedia.com/sopa/monkey_vs_robot.mp4
# 55    20120118  http://www.arckinteractive.com/sopa/monkey_vs_...
# 57    20120118  http://www.vizemedia.com/sopa/monkey_vs_robot.mp4
#
#                filename extension mime_type_web_server mime_type_tika  \
# 8   monkey_vs_robot.mp4       mp4           text/plain      video/mp4
# 10  monkey_vs_robot.mp4       mp4            video/mp4      video/mp4
# 55  monkey_vs_robot.mp4       mp4           text/plain      video/mp4
# 57  monkey_vs_robot.mp4       mp4            video/mp4      video/mp4
#
#                                  md5                                      sha1
# 8   d5d1475bd4bf11256459328e7bf42e2a  ad17595676625870869271389d0836ae185e742f
# 10  d5d1475bd4bf11256459328e7bf42e2a  ad17595676625870869271389d0836ae185e742f
# 55  d5d1475bd4bf11256459328e7bf42e2a  ad17595676625870869271389d0836ae185e742f
# 57  d5d1475bd4bf11256459328e7bf42e2a  ad17595676625870869271389d0836ae185e742f

# %% [markdown]
# ### What are the top 10 most occuring filenames in the collection?
#
# Note that this is of course different than the MD5 results up above. Here we are focusing _just_ on filename. So `silence.mp3` for example, might actually be referring to different video files who happen to have the same name.
#
# Here we can use `value_counts()` again, but this time we'll create a variable for the top filenames so we can use it later.

# %%
top_filenames = video["filename"].value_counts().head(10)
top_filenames
# Out:
# monkey_vs_robot.mp4                4
# sopafairuseprotest_120117b.mp4     2
# tumblr_lxznjdGNUe1r7udvz.mp4       2
# medium_std.mp4                     2
# medium1_std.mp4                    2
# bookkeepingcourse.flv              2
# handbags.wmv                       2
# tumblr_lklm9ulRc41qe3twr_r1.mov    2
# tumblr_lxyo8u4Sbs1r5ak3a_r2.mov    2
# tumblr_lxr190kriJ1qb9ff2.mp4       2
# Name: filename, dtype: int64

# %% [markdown]
# ### Let's create our first graph!
#
# We'll first plot the data with the pandas [plot](https://pandas.pydata.org/docs/reference/api/pandas.Series.plot.html) functionality, and then with [Altair](https://altair-viz.github.io/).

# %%
top_filenames_chart = top_filenames.plot.bar(figsize=(25, 10))

top_filenames_chart.set_title("Top Filenames", fontsize=22)
top_filenames_chart.set_xlabel("Filename", fontsize=20)
top_filenames_chart.set_ylabel("Count", fontsize=20)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Now let's setup [Altair](https://altair-viz.github.io/), and plot the data. Altair is useful for creating vizualizations since they can be easily exported as a PNG or SVG.

# %%
import altair as alt

# %%
top_filenames_altair = (
    video["filename"]
    .value_counts()
    .head(10)
    .rename_axis("Filename")
    .reset_index(name="Count")
)

filenames_bar = (
    alt.Chart(top_filenames_altair)
    .mark_bar()
    .encode(x=alt.X("Filename:O", sort="-y"), y=alt.Y("Count:Q"))
)

filenames_rule = (
    alt.Chart(top_filenames_altair).mark_rule(color="red").encode(y="mean(Count):Q")
)


filenames_text = filenames_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(filenames_bar + filenames_rule + filenames_text).properties(
    width=1400, height=700, title="Top Filenames"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### How about a file format distribution?
#
# What _kind_ of video files are present? We can discover this by checking their "media type", or [MIME type](https://en.wikipedia.org/wiki/Media_type).

# %%
video_mime_types = (
    video["mime_type_tika"]
    .value_counts()
    .head(5)
    .rename_axis("MIME Type")
    .reset_index(name="Count")
)

video_mimes_bar = (
    alt.Chart(video_mime_types)
    .mark_bar()
    .encode(x=alt.X("MIME Type:O", sort="-y"), y=alt.Y("Count:Q"))
)

video_mime_rule = (
    alt.Chart(video_mime_types).mark_rule(color="red").encode(y="mean(Count):Q")
)

video_mime_text = video_mimes_bar.mark_text(align="center", baseline="bottom").encode(
    text="Count:Q"
)

(video_mimes_bar + video_mime_rule + video_mime_text).properties(
    width=1400, height=700, title="video File Format Distribution"
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### How do I get the actual video?
#
# ...or, how do I get to the actual binary files described by each file format information derivative?
#
# There are a few options!
#
# 1. `wget` or `curl` from the live URL, or a replay URL
#   * Live web URL
#     * `wget` or `curl` the value of the `url` column
#   * Replay web URL
#     * `wget` or `curl` the value of the `crawl_date` and `url` column using the following pattern:
#       * `https://web.archive.org/web/` + `crawl_date` + `/` + `url`
#         * https://web.archive.org/web/20120119124734/http://www.archive.org/images/glogo.png
#       * `http://wayback.archive-it.org/14462/` + `crawl_date` + `/` + `url`
#         * https://wayback.archive-it.org/14462/20210524212740/https://ruebot.net/visualization/elxn42/featured_hu33a17dfb90e2c5ed77f783db14a6e53a_5126291_550x0_resize_q90_box_2.png
# 2. Use a scripting language, such as Python
#   * Make use of the `url` and `filename` columns (and `crawl_date` if you want to use the replay URL)
#   * `import requests`
#   * `requests.get(url, allow_redirects=True)`
#   * `open('filename', 'wb').write(r.content)`
# 3. Use the [Archives Unleashed Toolkit](https://aut.docs.archivesunleashed.org/docs/extract-binary) (if you have access to the W/ARC files).

# %% [markdown]
# If you wanted to download the video files using the replay URL, below is a method for doing so.
#
# First, you'll want to setup a replay url base url. Here we'll use the Archive-It Wayback instance for the collection.

# %%
wayback_url = 'http://wayback.archive-it.org/89/'

# %% [markdown]
# Next we'll create a new column using a lambda function. If you're familiar working with Spreadsheets, what we're doing here is basically concatenating some column values together and creating a new column.

# %%
video['replay_url'] = video.apply(lambda row: str(wayback_url + str(row['crawl_date']) + "/" + row['url']), axis=1)

# %% [markdown]
# Then we can export that new column we created out to a file, so we can use it with `wget` to download all the video files!

# %%
video['replay_url'].to_csv('89_video_urls.txt', index=False, header=False)

# %% [markdown]
# Finally, we can pass the file to `wget` to use as a download list. You can also speed this process up using `xargs` or `parallel`.

# %%
# !wget --random-wait -i 89_video_urls.txt
# Out:
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://rawreplaymedia.com/media/2011/1111/sopafairuseprotest_120117b.mp4
# Resolving wayback.archive-it.org (wayback.archive-it.org)... 207.241.232.8, 207.241.225.8
# Connecting to wayback.archive-it.org (wayback.archive-it.org)|207.241.232.8|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘sopafairuseprotest_120117b.mp4’
#
# sopafairuseprotest_     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (25.6 MB/s) - ‘sopafairuseprotest_120117b.mp4’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lklm9ulRc41qe3twr_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lklm9ulRc41qe3twr_r1.mov’
#
# tumblr_lklm9ulRc41q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (9.60 MB/s) - ‘tumblr_lklm9ulRc41qe3twr_r1.mov’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lrmu4x31Bf1qf1zsf.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lrmu4x31Bf1qf1zsf.mp4’
#
# tumblr_lrmu4x31Bf1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (21.3 MB/s) - ‘tumblr_lrmu4x31Bf1qf1zsf.mp4’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lxl7ypR3p21qggwnf.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxl7ypR3p21qggwnf.mp4’
#
# tumblr_lxl7ypR3p21q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (26.0 MB/s) - ‘tumblr_lxl7ypR3p21qggwnf.mp4’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lxz2e036hr1qebu2l_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxz2e036hr1qebu2l_r1.mov’
#
# tumblr_lxz2e036hr1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (14.1 MB/s) - ‘tumblr_lxz2e036hr1qebu2l_r1.mov’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://www.esotech.org/wp-content/uploads/iStock/SMO.mp4video.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SMO.mp4video.mp4’
#
# SMO.mp4video.mp4        [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:44 (24.1 MB/s) - ‘SMO.mp4video.mp4’ saved [4613]
#
# --2022-11-24 12:24:44--  http://wayback.archive-it.org/89/20120118/http://atomicturnipstudios.com/wp-content/uploads/2011/12/LandMC4Preview.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘LandMC4Preview.flv’
#
# LandMC4Preview.flv      [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (20.9 MB/s) - ‘LandMC4Preview.flv’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lxuxk2wWT71r3itiy.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxuxk2wWT71r3itiy.mp4’
#
# tumblr_lxuxk2wWT71r     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (21.7 MB/s) - ‘tumblr_lxuxk2wWT71r3itiy.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://www.arckinteractive.com/sopa/monkey_vs_robot.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘monkey_vs_robot.mp4’
#
# monkey_vs_robot.mp4     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (28.0 MB/s) - ‘monkey_vs_robot.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://www.maketheclearsolution.net/media/crrepairnew.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘crrepairnew.mp4’
#
# crrepairnew.mp4         [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (37.4 MB/s) - ‘crrepairnew.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://www.vizemedia.com/sopa/monkey_vs_robot.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘monkey_vs_robot.mp4.1’
#
# monkey_vs_robot.mp4     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (33.0 MB/s) - ‘monkey_vs_robot.mp4.1’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://uzlietuva.lt/files/videos/13165164780deed.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘13165164780deed.flv’
#
# 13165164780deed.flv     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (25.5 MB/s) - ‘13165164780deed.flv’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://uzlietuva.lt/files/videos/131444212258983.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘131444212258983.flv’
#
# 131444212258983.flv     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (29.6 MB/s) - ‘131444212258983.flv’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://video.ted.com/talk/stream/2010/Blank/MarianBantjes_2010-320k.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘MarianBantjes_2010-320k.mp4’
#
# MarianBantjes_2010-     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (35.9 MB/s) - ‘MarianBantjes_2010-320k.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://www.thehomelesscomedytour.org/THCT_Promo.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘THCT_Promo.flv’
#
# THCT_Promo.flv          [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (9.56 MB/s) - ‘THCT_Promo.flv’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://www.esotech.org/wp-content/uploads/iStock/Lightning_Slider_1.mp4video.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Lightning_Slider_1.mp4video.mp4’
#
# Lightning_Slider_1.     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (35.5 MB/s) - ‘Lightning_Slider_1.mp4video.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lxz2e036hr1qebu2l_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxz2e036hr1qebu2l_r1.mov.1’
#
# tumblr_lxz2e036hr1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (27.2 MB/s) - ‘tumblr_lxz2e036hr1qebu2l_r1.mov.1’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120119/http://videos.mozilla.org/serv/webfwd/webfwd_promotion.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘webfwd_promotion.mp4’
#
# webfwd_promotion.mp     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (26.7 MB/s) - ‘webfwd_promotion.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120119/http://cf.cdn.vid.ly/3d2c1n/mp4.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘mp4.mp4’
#
# mp4.mp4                 [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:45 (37.6 MB/s) - ‘mp4.mp4’ saved [4613]
#
# --2022-11-24 12:24:45--  http://wayback.archive-it.org/89/20120119/http://videos.mozilla.org/serv/qa/QMO/QMO_intro_intl.m4v
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘QMO_intro_intl.m4v’
#
# QMO_intro_intl.m4v      [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24
mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxsa3wAZ3x1qf1kxj.mp4’
#
# tumblr_lxsa3wAZ3x1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (34.2 MB/s) - ‘tumblr_lxsa3wAZ3x1qf1kxj.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lxwhbpYjHa1qke3bk_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxwhbpYjHa1qke3bk_r1.mov’
#
# tumblr_lxwhbpYjHa1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (29.3 MB/s) - ‘tumblr_lxwhbpYjHa1qke3bk_r1.mov’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lu1zouy6QR1qzv9mh_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lu1zouy6QR1qzv9mh_r1.mov’
#
# tumblr_lu1zouy6QR1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (12.9 MB/s) - ‘tumblr_lu1zouy6QR1qzv9mh_r1.mov’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lxtr2xycbY1qm92ut.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxtr2xycbY1qm92ut.mp4’
#
# tumblr_lxtr2xycbY1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (25.8 MB/s) - ‘tumblr_lxtr2xycbY1qm92ut.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://k003.kiwi6.com/hotlink/1w697374vj/zgintro.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘zgintro.flv’
#
# zgintro.flv             [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (25.0 MB/s) - ‘zgintro.flv’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://benfinoradin.info/destroy.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘destroy.mov’
#
# destroy.mov             [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (30.4 MB/s) - ‘destroy.mov’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lrn0a80eSY1qf1zsf.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lrn0a80eSY1qf1zsf.mp4’
#
# tumblr_lrn0a80eSY1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (33.5 MB/s) - ‘tumblr_lrn0a80eSY1qf1zsf.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lughc51qj21r4y9tm_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lughc51qj21r4y9tm_r1.mov’
#
# tumblr_lughc51qj21r     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (15.5 MB/s) - ‘tumblr_lughc51qj21r4y9tm_r1.mov’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_llb20lNwLd1qcd0gp.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_llb20lNwLd1qcd0gp.mp4’
#
# tumblr_llb20lNwLd1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (19.5 MB/s) - ‘tumblr_llb20lNwLd1qcd0gp.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://j45.video2.blip.tv/6560006747298/Miropcf-AboutUniversalSubtitles715.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Miropcf-AboutUniversalSubtitles715.mp4’
#
# Miropcf-AboutUniver     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (25.2 MB/s) - ‘Miropcf-AboutUniversalSubtitles715.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lxwy3erFRe1qi0lw9.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxwy3erFRe1qi0lw9.mp4’
#
# tumblr_lxwy3erFRe1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (30.0 MB/s) - ‘tumblr_lxwy3erFRe1qi0lw9.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://vt.tumblr.com/tumblr_lxm79hr72C1qbypel.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxm79hr72C1qbypel.mp4’
#
# tumblr_lxm79hr72C1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (25.2 MB/s) - ‘tumblr_lxm79hr72C1qbypel.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://videos.watchdocumentary.com/Louis_Theroux_Americas_Most_Dangerous_Pets.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Louis_Theroux_Americas_Most_Dangerous_Pets.mp4’
#
# Louis_Theroux_Ameri     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (15.1 MB/s) - ‘Louis_Theroux_Americas_Most_Dangerous_Pets.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120119/http://www.stormchaser1.net/uploads/SH1.wmv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘SH1.wmv’
#
# SH1.wmv                 [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (28.3 MB/s) - ‘SH1.wmv’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120119/http://videos-cdn.mozilla.net/brand/Mozilla_2011_Story.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Mozilla_2011_Story.mp4’
#
# Mozilla_2011_Story.     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (36.4 MB/s) - ‘Mozilla_2011_Story.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120119/http://videos-cdn.mozilla.net/serv/webmademovies/Moz_Doc_0329_GetInvolved_ST.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Moz_Doc_0329_GetInvolved_ST.mp4’
#
# Moz_Doc_0329_GetInv     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:47 (34.6 MB/s) - ‘Moz_Doc_0329_GetInvolved_ST.mp4’ saved [4613]
#
# --2022-11-24 12:24:47--  http://wayback.archive-it.org/89/20120118/http://www.arckinteractive.com/sopa/monkey_vs_robot.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘monkey_vs_robot.mp4.2’
#
# monkey_vs_robot.mp4     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (26.8 MB/s) - ‘monkey_vs_robot.mp4.2’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://www.maketheclearsolution.net/media/crrepairnew.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘crrepairnew.mp4.1’
#
# crrepairnew.mp4.1       [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (29.6 MB/s) - ‘crrepairnew.mp4.1’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://www.vizemedia.com/sopa/monkey_vs_robot.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘monkey_vs_robot.mp4.3’
#
# monkey_vs_robot.mp4     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (31.2 MB/s) - ‘monkey_vs_robot.mp4.3’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://uzlietuva.lt/files/videos/131763367090c0c.flv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘131763367090c0c.flv’
#
# 131763367090c0c.flv     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (20.8 MB/s) - ‘131763367090c0c.flv’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://rawreplaymedia.com/media/2011/1111/sopafairuseprotest_120117b.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘
[ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (15.0 MB/s) - ‘tumblr_lxnesrwobb1qd0ekl.mp4.1’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://www.route1radio.com/images/advertisement/b-collective/handbags.wmv
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘handbags.wmv.1’
#
# handbags.wmv.1          [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (23.4 MB/s) - ‘handbags.wmv.1’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lp2054vW8K1qh3rpf_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lp2054vW8K1qh3rpf_r1.mov.1’
#
# tumblr_lp2054vW8K1q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:48 (32.3 MB/s) - ‘tumblr_lp2054vW8K1qh3rpf_r1.mov.1’ saved [4613]
#
# --2022-11-24 12:24:48--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lklm9ulRc41qe3twr_r1.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lklm9ulRc41qe3twr_r1.mov.1’
#
# tumblr_lklm9ulRc41q     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (29.3 MB/s) - ‘tumblr_lklm9ulRc41qe3twr_r1.mov.1’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://v.tumblr.com/tumblr_lxyo8u4Sbs1r5ak3a_r2.mov
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tumblr_lxyo8u4Sbs1r5ak3a_r2.mov.1’
#
# tumblr_lxyo8u4Sbs1r     [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (108 MB/s) - ‘tumblr_lxyo8u4Sbs1r5ak3a_r2.mov.1’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/XUCJfkbU/medium1_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium1_std.mp4’
#
# medium1_std.mp4         [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (27.3 MB/s) - ‘medium1_std.mp4’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/P6lGryVS/medium_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium_std.mp4’
#
# medium_std.mp4          [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (36.0 MB/s) - ‘medium_std.mp4’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/QOMfLyhd/medium_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium_std.mp4.1’
#
# medium_std.mp4.1        [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (31.6 MB/s) - ‘medium_std.mp4.1’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/kAklr7b3/medium1_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium1_std.mp4.1’
#
# medium1_std.mp4.1       [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (28.8 MB/s) - ‘medium1_std.mp4.1’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/uOAvoIIV/medium2_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium2_std.mp4’
#
# medium2_std.mp4         [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (18.1 MB/s) - ‘medium2_std.mp4’ saved [4613]
#
# --2022-11-24 12:24:49--  http://wayback.archive-it.org/89/20120118/http://videos.videopress.com/RmvNfrSj/medium3_std.mp4
# Reusing existing connection to wayback.archive-it.org:80.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘medium3_std.mp4’
#
# medium3_std.mp4         [ <=>                ]   4.50K  --.-KB/s    in 0s
#
# 2022-11-24 12:24:49 (23.6 MB/s) - ‘medium3_std.mp4’ saved [4613]
#
# FINISHED --2022-11-24 12:24:49--
# Total wall clock time: 5.0s
# Downloaded: 79 files, 356K in 0.02s (22.8 MB/s)
